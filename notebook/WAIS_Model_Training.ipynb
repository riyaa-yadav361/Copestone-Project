# %% [markdown]
# # WAIS Model Training and HR Analytics
# This notebook demonstrates the Workforce Attrition Intelligence System: data cleaning, analysis, machine learning training, NLTK-based recommendation generation, and model export.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import joblib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
nltk.download('punkt', quiet=True)

# %%
df = pd.read_csv('../data/HR_Employee_Attrition.csv')
print('Dataset shape:', df.shape)
print(df.head())

# %%
# Data quality checks
missing = df.isnull().sum().sort_values(ascending=False)
print(missing[missing > 0])
print(df.dtypes)

# %%
# Clean the data by removing administrative columns that are not predictive
drop_columns = ['EmployeeCount', 'Over18', 'StandardHours', 'EmployeeNumber']
df = df.drop(columns=[col for col in drop_columns if col in df.columns], errors='ignore')
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
    

: 
,
: null,
: {},
: [],
: [
,
6
,
,
,
,
,
,
,
6
,
,
,
,
,

: 
,
: null,
: {},
: [],
: [
,

: 
,
: null,
: {},
: [],
: [
,
,
